# %% [markdown]
# ### Exercise 1 (20 points)
# Dictionaries have a method called **`get`** that takes a key and a default value. If the key appears in the dictionary, **`get`** returns the corresponding value; otherwise it returns the default value. For example, here’s a dictionary that maps from the letters in a string to the number of times they appear:
#
# ![image.png](attachment:56df11b9-6261-4144-946d-a97bb373006e.png)
#
# If we look up a letter that appears in the word, **`get`** returns the number of times it appears:
#
# ![image.png](attachment:14f36b96-4684-4b7b-bd9e-5533fa40f5c1.png)
#
# If we look up a letter that doesn’t appear, we get the default value, 0:
#
# ![image.png](attachment:b103451c-43be-46cf-8958-9471b59d99a3.png)
#
# Use **`get`** to write a more concise version of **`value_counts`**. You should be able to eliminate the **`if`** statement in **`value_counts`**.

# %%
def value_counts(s):
    counts = {}
    for letter in s:
        counts[letter] = counts.get(letter, 0) + 1
    return counts


counter = value_counts("brontosaurus")
print(counter)

# %% [markdown]
# ### Exercise 2 (20 points)
# What is the longest word you can think of where each letter appears only once? Let’s see if we can find one longer than **unpredictably**.
#
# Write a function named **`has_duplicates`** that takes a sequence—like a list or string as a parameter and returns **`True`** if there is any element that appears in the sequence more than once.

# %%
def has_duplicates(word):
    return len(word) != len(set(word))

print(has_duplicates("hello"))
print(has_duplicates("world"))

# %% [markdown]
# ## Exercise 3 (20 points)
# Write a function called **`find_repeats`** that takes a dictionary that maps from each key to a counter, like the result from  **`value_counts`**. It should loop through the dictionary and return a list of keys that have counts greater than 1. You can use the following outline to get started:
#
# ![image.png](attachment:775dcceb-043d-4d52-a3b2-bc7b2775ac8d.png)

# %%
def value_counts(s):
    counts = {}
    for letter in s:
        counts[letter] = counts.get(letter, 0) + 1
    return counts


def find_repeats(counter):
    return [key for key, count in counter.items() if count > 1]


text = "brontosaurus"
counter = value_counts(text)
repeats = find_repeats(counter)
print("Repeated letters:", repeats)

# %% [markdown]
# ### Exercise 4 (20 points)
# Suppose you run **`value_counts`** with two different words and save the results in two dictionaries:
#
# ![image.png](attachment:67ffafdd-e8dc-452d-9cc2-57393df9eb71.png)
#
# Each dictionary maps from a set of letters to the number of times they appear. Write a function called **`add_counters`** that takes two dictionaries like this and returns a new dictionary that contains all of the letters and the total number of times they appear in either word.

# %%
def value_counts(s):
    counts = {}
    for letter in s:
        counts[letter] = counts.get(letter, 0) + 1
    return counts


def add_counters(dict1, dict2):
    combined = {}
    for key in set(dict1) | set(dict2):
        combined[key] = dict1.get(key, 0) + dict2.get(key, 0)
    return combined


text = "brontosaurus"
text1 = "apatosaurus"
counter = value_counts(text)
counter1 = value_counts(text1)
print(counter)
print(counter1)
print("Add Counter:", add_counters(counter, counter1))

# %% [markdown]
# ### Exercise 5 (20 points)
# A word is “interlocking” if we can split it into two words by taking alternating letters. For example, “schooled” is an interlocking word because it can be split into “shoe” and “cold.”
#
# To select alternating letters from a string, you can use a slice operator with three components that indicate where to start, where to stop, and the “step size” between the letters.
#
# In the following slice, the first component is 0, so we start with the first letter. The second component is **`None`**, which means we should go all the way to the end of the string. And the third component is 2, so there are two steps between the letters we select:
#
# ![image.png](attachment:6af9a8fd-c6e2-4a00-868c-178f51059737.png)
#
# Instead of providing **`None`** as the second component, we can get the same effect by leaving it out altogether. For example, the following slice selects alternating letters, starting with the second letter:
#
# ![image.png](attachment:804fc9dc-f5b1-47cf-b411-c6d2a71c56ca.png)
#
# Write a function called **`is_interlocking`** that takes a word as an argument and returns **`True`** if it can be split into two interlocking words.

# %%
def is_interlocking(word, word_set):
    word1 = word[::2]  # Characters at even indices
    word2 = word[1::2]  # Characters at odd indices
    if word1 in word_set and word2 in word_set:
        return True
    return False


print(
    "Interlocking words:",
    is_interlocking("schooled", {"shoe", "cold"}),
)
